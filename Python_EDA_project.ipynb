# %% [markdown]
# <a href="https://colab.research.google.com/github/Thishna/Thishna-Data_Science_Projects/blob/Data-Science/Python_EDA_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - REVOLUTIONALIZING HOSPITALITY

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# %%
set(stopwords.words('english'))

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** THISHNA K
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# The data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces,etc. There are about 1,19,390 values available in which they have mentioned about the hotel the customer has booked and 31 other informations also.
#
# This project analyzed hotel booking data to gain insights into guest behavior and improve booking strategies. The data included reservation information, guest details, and room rates. I performed data cleaning to address missing values and inconsistencies.
#
# The insights done in project will be helpful to increase the revenue. The project demonstrates the value of data analysis in optimizing hotel operations and revenue generation.
#
# Data analysis plays a crucial role in improving hotel bookings by providing valuable insights into guest behavior, booking patterns, and market trends.
#
# Understanding Guest Behavior:
#
# Segmentation: Data analysis helps segment guests based on demographics, booking habits (length of stay, frequency), and travel purposes (business vs. leisure). This allows hotels to tailor marketing messages and promotions to specific guest segments, increasing booking conversions.
# Identifying booking patterns: Analyzing historical booking data reveals trends in booking lead times, peak seasons, and room type preferences. This knowledge helps hotels optimize inventory management and pricing strategies.
# Analyzing cancellation rates: By understanding reasons for cancellations (price, amenities, cancellation policies), hotels can identify areas for improvement and implement strategies to reduce cancellations (e.g., flexible policies, last-minute deals).
#
# Dynamic Pricing: Analyze historical booking data, competitor pricing, and local events to set dynamic room rates that maximize revenue while remaining competitive.
# Demand Forecasting: Predict future demand based on historical data and market trends. This helps with inventory management, staffing levels, and anticipating peak seasons.
# Optimizing Distribution Channels: Analyze the effectiveness of different booking channels (website, OTAs) to allocate resources and marketing efforts effectively.
#
# Optimizing Pricing Strategies:
# Revenue Management: Data analysis helps determine optimal room rates based on factors like seasonality, competitor pricing, and local events. This ensures hotels maximize revenue without deterring bookings with excessively high prices.
# Dynamic Pricing: Hotels can leverage data to implement dynamic pricing strategies, adjusting rates in real-time based on demand. This allows them to capture higher rates during peak periods and offer competitive rates during slower times.
# Enhancing Marketing Campaigns:
#
# Targeted advertising: Data analysis helps identify the demographics and online behavior of potential guests. Hotels can then target their advertising campaigns on relevant platforms (social media, travel websites) to reach the right audience, maximizing the return on investment (ROI) for marketing efforts.
# Personalized offers: Guest data can be used to personalize email marketing campaigns and website recommendations. Offering targeted deals based on past stays and preferences can entice guests to book again.
#
# Overall, data analysis empowers hotels to:
# Make data-driven decisions to improve efficiency and profitability.
# Personalize the guest experience to enhance satisfaction and loyalty.
# Gain a competitive edge in the ever-evolving hospitality industry.
# By implementing a data-driven approach, hotels can unlock valuable insights from their booking data and significantly improve their booking rates and overall business performance.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/Thishna/Python-colab-EDA.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# The hotel industry faces a dynamic landscape with competition from alternative accommodations like Airbnb and new hotel chains emerging constantly.  Furthermore, economic fluctuations and shifting travel trends can significantly impact booking rates.
# In this context, traditional methods of hotel management may not be sufficient to optimize occupancy and revenue.  This is where data analysis becomes crucial.
# Hotel booking data holds a wealth of untapped potential.  Unfortunately, this data often remains unanalyzed, leading to missed opportunities.  Without leveraging data, hotels struggle to understand:
#
# Guest behavior: Why do bookings fluctuate? What influences cancellations?
#
# Market trends: Are there seasonal patterns or new travel preferences we should cater to?
#
# Pricing strategies: Are we maximizing revenue with our current pricing model?
#
# Distribution channels: Which booking platforms are most effective in reaching our target audience?
#
# By failing to address these questions, hotels risk:
#
# Lower occupancy rates: Missing opportunities to attract new guests and fill rooms.
# Reduced revenue: Inability to optimize pricing and upselling strategies.
#
# Poor guest experience: Not understanding guest needs and preferences.
# Effectively analyzing hotel booking data holds the key to unlocking valuable insights that can revolutionize hotel operations and booking strategies.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
# To increase the rate of bookings thereby increasing the income.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %%
Path = '/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.xlsx'
df = pd.read_excel(Path)
df.head()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
df.isnull().sum().plot(kind='bar')

# %%
column_names = list(df.columns)
for i in column_names:
 unique_values = df[i].unique()
 unique_values_count = len(unique_values)
 print(f'Column {i} has {unique_values_count} unique values.')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Answer Here
#
# The given data set is of hotel booking. There are 119390 rows i.e., values and 32 columns are available in which 31994 are duplicates. The country column has 488 null values, agent column has 16340 null values and company column has 112593 null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
#
# Here's a summary of the dataset's columns:
#
# 1. **hotel:** Type of hotel (Resort Hotel or City Hotel)
# 2. **is_canceled:** If the booking was canceled (0 = No, 1 = Yes)
# 3. **lead_time:** Number of days between booking and arrival
# 4. **arrival_date_year:** Year of arrival date
# 5. **arrival_date_month:** Month of arrival date
# 6. **arrival_date_week_number:** Week number of the year for arrival
# 7. **arrival_date_day_of_month:** Day of arrival date
# 8. **stays_in_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# 9. **stays_in_week_nights:** Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# 10. **adults:** Number of adults
# 11. **children:** Number of children
# 12. **babies:** Number of babies
# 13. **meal:** Type of meal booked
# 14. **country:** Country of origin
# 15. **market_segment:** Market segment designation
# 16. **distribution_channel:** Booking distribution channel
# 17. **is_repeated_guest:** If the booking was from a repeated guest (0 = No, 1 = Yes)
# 18. **previous_cancellations:** Number of previous bookings that were cancelled by the customer prior to the current booking
# 19. **previous_bookings_not_canceled:** Number of previous bookings not cancelled by the customer prior to the current booking
# 20. **reserved_room_type:** Code of room type reserved
# 21. **assigned_room_type:** Code for the type of room assigned to the booking
# 22. **booking_changes:** Number of changes/amendments made to the booking from the moment the booking was created until the moment of check-in or cancellation
# 23. **deposit_type:** Type of deposit made by the guest (No Deposit, Non Refund, Refundable)
# 24. **agent:** ID of the travel agency that made the booking
# 25. **company:** ID of the company/entity that made the booking
# 26. **days_in_waiting_list:** Number of days the booking was in the waiting list before it was confirmed to the customer
# 27. **customer_type:** Type of customer (Transient, Contract, Group, Transient-Party)
# 28. **adr:** Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
# 29. **required_car_parking_spaces:** Number of car parking spaces required by the customer
# 30. **total_of_special_requests:** Total number of special requests made by the customer (e.g. high floor, crib, etc.)
# 31. **reservation_status:** Reservation last status (Canceled, Check-Out, No-Show)
# 32. **reservation_status_date:** Date at which the last status was set

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns:
  print(f'Unique values in {i} are {df[i].unique()}')

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
nan_replacements = {'children': 0.0, 'country': 'Unknown', 'agent': 0, 'company': 0}
df1 = df.fillna(nan_replacements)
df1.isna().sum()
df1

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# In the given data, there were 4 missing values for children, 488 for country, 16340 for agent and 112593 for company.
# Since children, agent and company has integer data type values, I replaced the missing values with 0. Since country has string data type values, I replaced the missing values with Unknown.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure() #creates a new figure for plotting. It ensures that the plot is created in a new, clean figure.
ax = sns.countplot(x= 'hotel', hue='is_canceled', data=df1, palette='Reds') #creates a count plot, which displays the count of observations in each categorical bin using bars.
legend_labels,_ = ax.get_legend_handles_labels() #store the labels for the legend, but it isn't further used in this code snippet.
plt.title('Lead time vs Cancellation status', size=15) #Sets the title of the plot.
plt.show() #Displays the plot.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Bar plot is an effective and intuitive choice for visualizing the distribution of hotel bookings and their cancellation status, allowing for easy comparison and clear communication of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 1. Resort Hotel Bookings:
# *   The majority of bookings are not canceled.
# *  There is a significant but smaller number of cancellations.
#
# 2. City Hotel Bookings:
#
# *   The number of non-canceled bookings is higher than the number of canceled bookings, but both are substantial.
#
# The City Hotel has a higher total number of bookings compared to the Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# City Hotel has a higher overall booking count compared to the Resort Hotel.
# Both hotels show a trend where non-canceled bookings outnumber canceled bookings.
# The difference between non-canceled and canceled bookings is more pronounced in the Resort Hotel compared to the City Hotel, indicating that the City Hotel has a relatively higher proportion of cancellations.
# Possible Implications
#
# Hotel Management:
#
# Resort Hotel might want to investigate why the cancellation rate is lower compared to City Hotel and if there are specific factors contributing to more stable bookings.
# City Hotel may need to explore reasons behind the higher cancellation rates and implement strategies to reduce cancellations (e.g., flexible booking policies, incentives for non-cancellation).

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
pivot_table = df1.pivot_table(index='deposit_type', columns='is_canceled', values='lead_time', aggfunc='count') #Creates a pivot table from the DataFrame df1
print(pivot_table)
pivot_table.plot(kind='bar', stacked=True) #Plots the pivot table

#Customization
plt.title('Comparison of deposit type and cancellation')
plt.xlabel('Deposit type')
plt.ylabel('Number of instances')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# This visual representation can aid in identifying trends and patterns, such as which deposit types have higher or lower cancellation rates. Such insights are valuable for decision-making and strategizing in various domains like marketing, customer service, and operational planning.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 1. No Deposit:
# * This category has the highest number of bookings.
# * There is a significant proportion of cancellations (orange section), but the majority of bookings are not canceled (blue section).
# * The height of the bar indicates that most customers prefer No Deposit bookings, although a notable portion of these bookings gets canceled.
#
# 2. Non Refund:
# * The number of bookings in this category is significantly lower compared to No Deposit.
# * A substantial proportion of these bookings is canceled, as indicated by the orange section.
# * This suggests that customers who opt for Non Refund are more likely to cancel their bookings, possibly due to stricter cancellation policies or higher initial costs.
#
# 3. Refundable:
# * This category has the fewest bookings, with a very small bar height.
# * Both canceled and non-canceled bookings are minimal.
# * The low number of bookings in this category might suggest that customers are less attracted to Refundable deposits, possibly due to higher upfront costs or lower perceived value.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# 1. Marketing and Pricing Strategies:
# * No Deposit: Since this category is popular but has a noticeable cancellation rate, strategies could focus on offering incentives for keeping bookings or implementing flexible cancellation policies to reduce cancellations.
#
# * Non Refund: Given the high cancellation rate, reviewing the non-refundable policy or offering additional benefits for committing to non-refundable bookings might help in reducing cancellations.
#
# * Refundable: This category might need better promotion or adjustment in pricing to make it more attractive to customers.
#
# 2. Customer Behavior:
# * Customers prefer booking with no upfront deposit, possibly due to the flexibility it offers.
# * The high cancellation rate in Non Refund might indicate that customers book this option as a backup or change their plans more frequently when there's a non-refundable deposit.
#
# 3. Operational Adjustments:
# * Understanding the high preference for No Deposit bookings can help in better planning and resource allocation, anticipating higher booking volumes and potential cancellations.
# * Strategies could be devised to manage the high cancellation rates in both No Deposit and Non Refund categories to minimize revenue losses and improve booking stability.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(13, 7), dpi=80)
ax = sns.countplot(x= 'market_segment', hue='is_canceled', data=df, palette='bright')
legend_labels,_ = ax.get_legend_handles_labels()

plt.title('Market segment vs Cancellation status', size=15)
plt.ylabel('Counts of Cancellation status 0 (NotCancelled) 1 (Cancelled) ')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Bar charts are easy to read and understand, and they are a good way to compare different categories.
#
# * It can easily show a comparison between different categories. In this case, it is clear to see that the Direct market segment has the most cancellations, followed by the Corporate market segment.
# * It can be used to show data that is not continuous. In this case, the number of cancellations is a count, which is not continuous data.
# * It is easy to create and understand. Bar charts are one of the most common types of charts, and most people are familiar with how to read them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * The market segment with the most cancellations is Direct, with over 30,000 cancellations.
# * The market segment with the fewest cancellations is Undefined, with fewer than 5,000 cancellations.
# * The corporate market segment has more cancellations than the online travel agent (OTA) market segment.
# * The complementary market segment has very few cancellations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# It is important to note that the graph does not show the total number of bookings for each market segment. It is possible that the market segments with the most cancellations also have the most bookings. Without knowing the total number of bookings, it is difficult to say which market segment has the highest cancellation rate.
#
# Here are some additional questions that you might want to consider:
#
# * What is the company's overall cancellation rate?
# * What are the reasons for cancellation for each market segment?
# * Are there any trends in the cancellation data over time?
#
# By answering these questions, the company can gain a better understanding of its cancellation problem and develop strategies to reduce cancellations.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(13, 6), dpi=80)
ax=sns.countplot(x='previous_cancellations', hue='is_canceled', data=df1, palette='dark')

legend_labels,_ = ax.get_legend_handles_labels()
plt.title('Previous cancellation vs Cancellation status', size=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * To compare different categories of data. Bar graphs are good at this because our eyes are good at judging the length of bars.
# * To show the frequency of something.
# * To show the parts of a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * The number of cancellations steadily declines as the number of previous cancellations increases. This suggests that customers who have used the service for a while are less likely to cancel.
# * There is a small uptick in cancellations at around 11 previous cancellations. It is possible that this is due to a specific program or promotion that was targeted at customers who had cancelled in the past.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# The insights from this bar graph can help you grow your business. The graph shows the number of cancellations compared to the cancellation status.  Cancellation status seems to be a categorical variable with values ranging from 0 to 26. It is difficult to say for sure what these categories represent without more context, but some possibilities are different reasons for cancellation or the number of times a customer has cancelled.
#
# The fact that the number of previous cancellations is higher than the number of cancellations for any given cancellation status suggests that most customers who cancel do not cancel again. This could be good news for your business, as it suggests that you are not losing a significant number of customers to churn.
#
# However, it is also important to consider the overall number of cancellations. If the number of cancellations is high, even if they are not repeat cancellations, it could still be a cause for concern. You can use this graph to identify which cancellation statuses are most common and then investigate the reasons for those cancellations. This can help you to develop strategies to reduce cancellations and grow your business.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
average_price = df1.groupby('arrival_date_year')['adr'].mean().round(decimals=2)
print(average_price)
plt.figure(figsize=(9, 6), dpi=80)
average_price.plot(kind='line', marker='o', color='green')

plt.plot(average_price.index.values, average_price.values)
for ind,score in zip(average_price.index.values, average_price.values):
    plt.text(ind,score,str(score), fontweight='bold', fontsize=9)

plt.title('Average Hotel Price($) Over the Years', size=15)
plt.xlabel('Year')
plt.ylabel('Average Price($)')



plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * It is easy to see the overall trend in the data.
# * It is easy to compare the data points to each other.
# * Line graphs are a common and familiar type of chart, so most people will be able to understand it easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * The average hotel price has been increasing over the years. There has been a steady increase in price from 87.18 in 2015 to 114.64 in 2017.
# * It is likely that the average hotel price will continue to increase in the future. This is because the line graph is showing an upward trend

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Identify trends in hotel prices:  The line graph shows whether hotel prices are generally increasing, decreasing, or staying flat over time. This can inform your pricing strategy. For example, if you see that hotel prices are rising in the shoulder seasons (spring and fall), you might consider raising your rates during those times as well.
#
# Plan promotions strategically:  By understanding seasonal trends, you can plan promotions and discounts for times when hotel prices are typically lower. This can help you attract more guests during those periods.
#
# Target specific demographics: If you see that hotel prices are rising overall, you might consider targeting your marketing efforts to budget-conscious travelers. You can offer them amenities or packages that make your hotel a more attractive option.
#
# Focus on value proposition:  Regardless of whether prices are rising or falling, focus on the value proposition of your hotel. Highlight what makes your hotel unique and worth the price. This could be your location, amenities, customer service, or unique experiences.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
cancelled_data = df1[df1['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
print(top_10_country)

plt.figure(figsize = (7,7))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country,autopct = '%.2f',labels = top_10_country.index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * Show proportions of a whole: Pie charts are good at showing parts of a whole. In this case, the whole is all the reservation cancellations, and the slices of the pie represent the portion of cancellations from each country. This makes it easy to see which countries have the most cancellations at a glance.
#
# * Simple and easy to understand: Pie charts are a very common type of chart and most people are familiar with how to read them. This makes them a good choice for communicating information to a general audience.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * **Identify which countries have the most cancellations:**
#   The countries with the largest slices of pie represent the ones with the most reservation cancellations. By focusing your marketing efforts on countries with fewer cancellations, you might be able to improve your overall cancellation rate.
#
# * **Investigate reasons for cancellations from specific countries:**
# There could be specific reasons why people from certain countries are cancelling reservations more frequently. By researching these reasons, you might be able to take steps to address them and reduce cancellations. For example, if you see that a lot of cancellations from a particular country are happening because people are unhappy with the visa application process, you could provide more information on your website or app to help them through the process.
#
# * **Target marketing campaigns:** Once you’ve identified the countries with the most cancellations, you can avoid targeting them with expensive marketing campaigns. You can instead focus your efforts on countries that are more likely to convert.
#
# * **Re-evaluate pricing or offerings for specific countries:**  If you see a correlation between cancellations from a particular country and the price of your hotel stays or the packages you offer, you might want to consider adjusting your pricing or offerings for that country.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# The chart shows the top ten countries with reservation cancellations, with Portugal (PRT) having the most cancellations at 70.07%, followed by Belgium (BEL) at 7.27%.
#
# Here are some insights you can learn from this chart:
#
# * Identify target markets with high cancellation rates:  Countries with high cancellation rates might represent missed opportunities for your business. By understanding why these reservations are being cancelled, you can take steps to address those concerns and improve your conversion rate.
#
# * Analyze reasons for cancellations:  Investigate why people from these countries are cancelling reservations. Common reasons for cancellation include price, location, lack of desired amenities, or negative reviews from other guests. By addressing these concerns, you can make your hotel more appealing to travelers from these countries.
#
# * Target marketing efforts: Focus your marketing efforts on countries with high cancellation rates. You can tailor your message to address the specific concerns of travelers from those countries. For example, if price is a major concern for travelers from Portugal, you could offer discounts or promotions specifically for them.
#
# * Improve customer service:  Make sure your customer service is excellent, especially for guests from countries with high cancellation rates. This will help to build trust and encourage travelers to follow through with their reservations.
#
# * Re-evaluate pricing strategy:  Consider whether your pricing is competitive, especially in countries with high cancellation rates. You may need to adjust your prices to attract more travelers from these countries.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
revenue_by_countries = df1.groupby('country')['adr'].mean().round(decimals=2).head()
print(revenue_by_countries)

plt.figure(figsize=(9, 6), dpi=80)
revenue_by_countries.plot(kind='line', marker='o', color='green')

plt.plot(revenue_by_countries.index.values, revenue_by_countries.values)

for ind,score in zip(revenue_by_countries.index.values, revenue_by_countries.values):
    plt.text(ind,score,str(score), fontweight='bold', fontsize=9)

plt.title('Average Revenue($) by Countries', size=15)
plt.xlabel('Countries')
plt.ylabel('Average Revenue($)')


plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The chart is a line graph which is a good choice to show trends over time. This specific line graph shows the average revenue by country. Line graphs are ideal for this situation because they allow you to easily see how the average revenue changes across different countries.
#
# For example, the line graph shows that the average revenue is highest in ABW (presumably Aruba) at 265.00 and lowest in AIA (presumably Anguilla) at $84.35. You can easily see the trends by following the lines.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * The average revenue per capita in the United States is equal to the average revenue per capita in the United Kingdom.
# * The countries with the lowest average revenue per capita are ABR, AGO, AIA, ALB, and AND.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# * **Focus on high-average revenue countries:** The United States has the highest average revenue according to this chart. You might want to consider investing more resources into marketing and sales in the US.
# * **Investigate lower-average revenue countries:** There could be a reason why the average revenue is lower in some countries. Maybe it's a pricing issue, or a lack of brand awareness. Investigating these reasons could help you identify opportunities to increase revenue in those countries.
# * **Consider the cost of doing business:** This chart only shows average revenue. You would also need to consider the cost of doing business in each country to determine profitability.
# * **Look at total revenue:** Overall revenue might be higher in a country with a lower average revenue simply because there are more sales.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
print(df1.groupby('hotel')['days_in_waiting_list'].sum())
plt.figure()
sns.barplot(data=df, x='days_in_waiting_list', y='hotel', hue='is_canceled')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * **Shows comparisons between categories:** This count plot is comparing the number of days a hotel was on the waiting list across three categories: Resort Hotel, City Hotel and Canceled. Count plots are well suited for this because our visual perception is good at interpreting the lengths of bars that have a common baseline
# * **Displays frequency data:** The data being visualized is the number of days each hotel was on the waiting list, which is a frequency. Count plots are specifically designed to show frequencies of categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * **Resort hotels tend to have the most wait times:**  The vast majority of nights spent waiting for a hotel room (across all wait times) are for resort hotels. There are a few possible reasons for this. Resort hotels may be more popular, and have higher occupancy rates. They may also be booked further in advance, especially for peak travel times.
#
# * **City hotels have shorter wait times:**  The vast majority of nights spent waiting for a city hotel room are for waits of 0 or 1 day. This suggests that city hotels may have lower occupancy rates, or that people tend to book them closer to their travel dates.
#
# * **There are very few waits of more than 2 days:**  The chart shows very few nights spent waiting for a hotel room for more than 2 days, regardless of hotel type. This suggests that most people are not willing to wait very long for a hotel room, and may look elsewhere if they cannot get a room right away.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# * **Reduce wait times:** Generally, you want to reduce the number of days people wait on a waiting list. This could be done by increasing inventory, or by improving forecasting to anticipate demand.
# * **Focus on resort hotels:** The chart shows that people are willing to wait longer for resort hotels than city hotels. You may want to investigate why this is the case (e.g. are resort hotels more scarce?) and see if there are ways to improve efficiency specifically for resort hotels.
# * **Track cancellations:** The chart only shows data for people who were not cancelled. It would be helpful to see how many cancellations occur at each wait time interval. This could help you identify opportunities to improve communication with people on the waiting list.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Calculate average revenue by hotel
revenue_by_hotel = df1.groupby('hotel')['adr'].mean().round(decimals=2)

# Create the bar chart (using revenue_by_hotel directly)
plt.figure(figsize=(10, 6))  # Optional: Set figure size for better visualization
sns.barplot(x=revenue_by_hotel.index, y=revenue_by_hotel.values)
plt.title('Average Revenue By Hotel')
plt.xlabel('Hotel Name')  # Add labels for clarity
plt.ylabel('Average Daily Rate')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# * **Categorical data:** The hotel names are categorical data, and bar charts are well-suited for comparing values of categorical variables.
# * **Emphasis on differences:** Bar charts are effective at highlighting differences between groups, which in this case are the average revenue between the city hotel and the resort hotel.
# * **Clarity and simplicity:** Bar charts are generally easy to understand, even for people who are not familiar with data visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * **Focus on attracting high-paying guests to the resort:** The resort hotel has a lower ADR despite potentially being able to command a higher price due to its location or amenities. Investigate what factors might be affecting the resort's ADR and see if there are ways to target a higher-paying clientele.
# * **Develop packages for the resort:** Offering packages that bundle activities or meals with accommodation could be a way to increase the perceived value and ADR for the resort.
# * **Highlight unique features of the resort:** Make sure the resort's unique features are well-communicated to potential guests. This could include luxury amenities, proximity to attractions, or special experiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# * **Focus on high-revenue hotel types:** The chart shows that city hotels have a higher average daily rate than resort hotels. You might want to consider ways to attract more guests to your city hotels, or to increase the average daily rate for your resort hotels.
# * **Investigate reasons for lower ADR in resort hotels:** There could be a reason why the ADR is lower in resort hotels. Maybe it's because they offer more amenities or larger rooms that cost more to maintain, or perhaps it's because they are located in seasonal destinations where rates fluctuate. Investigating these reasons could help you identify opportunities to increase revenue in resort hotels.
# * **Consider the cost of doing business:** This chart only shows average daily rate. You would also need to consider the cost of running each hotel type to determine profitability. For example, resort hotels may have higher operating costs due to location or amenities.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Calculate cancellation counts for repeated and non-repeated guests
cancellation_counts = df1.groupby('is_repeated_guest')['is_canceled'].sum()

# Create pie chart labels using a dictionary comprehension
legend_labels = {0: 'Not Repeated (0 Cancellations)', 1: 'Repeated (1 Cancellation)'}
pie_labels = [legend_labels[idx] for idx in cancellation_counts.index]

# Create the pie chart
fig = px.pie(
    names=pie_labels,
    values=cancellation_counts.values,
    title='Repeated Guests Vs Cancellation (Total Cancellations)',
    hole=0.5
)

# Update trace marker colors (optional, modify colors if needed)
fig.update_traces(marker=dict(colors=['cyan', 'pink']))

fig.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * It is a good choice to visualize the data in this case because it shows the proportions of two categorical variables: repeated guests and cancelled reservations. Pie charts are ideal for representing parts of a whole, and here the whole is all guest reservations (repeated and cancelled). Each slice of the pie represents the proportion of reservations that fall into that category.
#
# * **Easy to understand:** Pie charts are familiar to most people and can be understood quickly, even by those without experience with data visualization.
# * **Emphasis on relative sizes:** Pie charts can effectively highlight the relative sizes of the two categories (repeated guests vs. cancelled reservations). In this case, it is likely you want to emphasize the proportion of repeated guests to cancelled reservations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * **High customer retention:** The chart shows that a high percentage (85%) of guests are repeat guests, which is a positive sign. This suggests that guests are generally satisfied with their experience and are likely to return.
# * **Focus on reducing cancellations:** Even though the cancellation rate is relatively low (15%), there may still be opportunities to reduce it further. You can investigate the reasons why guests cancel and try to address those issues.
# * **Track reasons for cancellation:** The data doesn't show why guests are cancelling. Understanding the reasons for cancellation can help you identify areas for improvement.
# * **Target non-repeated guests:** Since non-repeated guests have a higher cancellation rate (15% vs 5%), you may want to target marketing efforts towards them to encourage them to return.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# * **Reduce guest cancellations:** The higher cancellation rate suggests there might be areas for improvement in the customer experience that are leading to cancellations. Investigating the reasons why guests are cancelling could help you identify areas for improvement.
# * **Survey departing guests:** One way to investigate the reasons for cancellation is to survey departing guests. You could ask them why they cancelled their reservation and what you could have done to prevent it.
# * **Track cancellation reasons:** If you don't already, you should track the reasons for cancellations. This data can help you identify patterns and trends that can be addressed.
# * **Target high-risk segments:** The chart doesn't show which guest segments are cancelling more, but you may want to consider segmenting your guest data to see if there are particular groups that are cancelling at a higher rate. You could then target these groups with special offers or loyalty programs.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
df2 = df1.drop('hotel',axis = 1)
df2.drop('arrival_date_month',axis = 1, inplace = True)
df2.drop('meal',axis = 1, inplace = True)
df2.drop('country',axis = 1, inplace = True)
df2.drop('market_segment',axis = 1, inplace = True)
df2.drop('distribution_channel',axis = 1, inplace = True)
df2.drop('reserved_room_type',axis = 1, inplace = True)
df2.drop('assigned_room_type',axis = 1, inplace = True)
df2.drop('deposit_type',axis = 1, inplace = True)
df2.drop('customer_type',axis = 1, inplace = True)
df2.drop('reservation_status',axis = 1, inplace = True)

# Calculate the correlation matrix
df2.corr()


# Create the heatmap
plt.figure(figsize=(20, 20))  # Optional: Adjust figure size for better visualization
sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')  # 'coolwarm' is a colormap choice

# Add labels and title
plt.title('Correlation Heatmap')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# The chart suitable for visualizing the relationship between different categories. It is a heatmap, which is better suited to  showing correlations between numerical variables. The heatmap shows the correlation between various metrics related to hotel bookings. Here, the color intensity indicates the strength of the correlation, with redder squares showing positive correlations and bluer squares showing negative correlations

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * There is a weak positive correlation between the number of adults and the number of children and babies that are booked (0.03 and 0.05 respectively). This means that bookings with more adults are slightly more likely to also have children and babies booked.
# * There is a weak positive correlation between booking changes and the total number of special requests (0.12). This could indicate that guests who make changes to their booking are also more likely to have additional requests.
# * There is a weak negative correlation between previous cancellations and the number of nights booked (both weeknights and weekend nights) This could mean that guests who have cancelled bookings in the past are less likely to book longer stays in the future.
# * There is a positive correlation between the reservation status date and the arrival date (0.9). This is likely because the reservation status date is typically set close to the arrival date.
# * Stays on weekdays and weekends seem to be negatively correlated (-0.02). This could mean that people don't tend to book both weekdays and weekend nights very often.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df1)

# Customize the plot (optional)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# * **Visualizing relationships between variables:**  A pair plot allows you to see how two variables are related to each other at a glance. This can be helpful for identifying patterns, trends, and outliers in your data.
#
# * Understanding data distributions:** The histograms along the diagonal of a pair plot show the distribution of each individual variable. This can help you see how the data is spread out and whether there are any skews.
#
# * **Creating a concise visualization:** Pair plots are a good way to summarize a lot of information in a single plot. This can be especially helpful for datasets with a moderate number of variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 1. **Marketing and Pricing Strategies:**
# * **No Deposit:** Since this category is popular but has a noticeable cancellation rate, strategies could focus on offering incentives for keeping bookings or implementing flexible cancellation policies to reduce cancellations.
#
# * **Non Refund:** Given the high cancellation rate, reviewing the non-refundable policy or offering additional benefits for committing to non-refundable bookings might help in reducing cancellations.
#
# * **Refundable:** This category might need better promotion or adjustment in pricing to make it more attractive to customers.
#
# 2. **Customer Behavior:**
# * Customers prefer booking with no upfront deposit, possibly due to the flexibility it offers.
# * The high cancellation rate in Non Refund might indicate that customers book this option as a backup or change their plans more frequently when there's a non-refundable deposit.
#
# 3. **Operational Adjustments:**
# * Understanding the high preference for No Deposit bookings can help in better planning and resource allocation, anticipating higher booking volumes and potential cancellations.
# * Strategies could be devised to manage the high cancellation rates in both No Deposit and Non Refund categories to minimize revenue losses and improve booking stability.
#
#
# * The market segment with the most cancellations is Direct, with over 30,000 cancellations.
# * The market segment with the fewest cancellations is Undefined, with fewer than 5,000 cancellations.
# * The corporate market segment has more cancellations than the online travel agent (OTA) market segment.
# * The complementary market segment has very few cancellations.
# * The number of cancellations steadily declines as the number of previous cancellations increases. This suggests that customers who have used the service for a while are less likely to cancel.
# * There is a small uptick in cancellations at around 11 previous cancellations. It is possible that this is due to a specific program or promotion that was targeted at customers who had cancelled in the past.
# * The average hotel price has been increasing over the years. There has been a steady increase in price from 87.18 in 2015 to 114.64 in 2017.
# * It is likely that the average hotel price will continue to increase in the future.
#
# * **Identify which countries have the most cancellations:**
#   The countries with the largest slices of pie represent the ones with the most reservation cancellations. By focusing your marketing efforts on countries with fewer cancellations, you might be able to improve your overall cancellation rate.
#
# * **Investigate reasons for cancellations from specific countries:**
# There could be specific reasons why people from certain countries are cancelling reservations more frequently. By researching these reasons, you might be able to take steps to address them and reduce cancellations. For example, if you see that a lot of cancellations from a particular country are happening because people are unhappy with the visa application process, you could provide more information on your website or app to help them through the process.
#
# * **Target marketing campaigns:** Once you’ve identified the countries with the most cancellations, you can avoid targeting them with expensive marketing campaigns. You can instead focus your efforts on countries that are more likely to convert.
#
# * **Re-evaluate pricing or offerings for specific countries:**  If you see a correlation between cancellations from a particular country and the price of your hotel stays or the packages you offer, you might want to consider adjusting your pricing or offerings for that country.
#
# * The average revenue per capita in the United States is equal to the average revenue per capita in the United Kingdom.
# * The countries with the lowest average revenue per capita are ABR, AGO, AIA, ALB, and AND.
#
# * **Reduce wait times:** Generally, you want to reduce the number of days people wait on a waiting list. This could be done by increasing inventory, or by improving forecasting to anticipate demand.
# * **Focus on resort hotels:** The chart shows that people are willing to wait longer for resort hotels than city hotels. You may want to investigate why this is the case (e.g. are resort hotels more scarce?) and see if there are ways to improve efficiency specifically for resort hotels.
# * **Track cancellations:** The chart only shows data for people who were not cancelled. It would be helpful to see how many cancellations occur at each wait time interval. This could help you identify opportunities to improve communication with people on the waiting list.
#
#
# * **Focus on high-revenue hotel types:** The chart shows that city hotels have a higher average daily rate than resort hotels. You might want to consider ways to attract more guests to your city hotels, or to increase the average daily rate for your resort hotels.
# * **Investigate reasons for lower ADR in resort hotels:** There could be a reason why the ADR is lower in resort hotels. Maybe it's because they offer more amenities or larger rooms that cost more to maintain, or perhaps it's because they are located in seasonal destinations where rates fluctuate. Investigating these reasons could help you identify opportunities to increase revenue in resort hotels.
# * **Consider the cost of doing business:** This chart only shows average daily rate. You would also need to consider the cost of running each hotel type to determine profitability. For example, resort hotels may have higher operating costs due to location or amenities.
#
# * **Reduce guest cancellations:** The higher cancellation rate suggests there might be areas for improvement in the customer experience that are leading to cancellations. Investigating the reasons why guests are cancelling could help you identify areas for improvement.
# * **Survey departing guests:** One way to investigate the reasons for cancellation is to survey departing guests. You could ask them why they cancelled their reservation and what you could have done to prevent it.
# * **Track cancellation reasons:** If you don't already, you should track the reasons for cancellations. This data can help you identify patterns and trends that can be addressed.
# * **Target high-risk segments:** The chart doesn't show which guest segments are cancelling more, but you may want to consider segmenting your guest data to see if there are particular groups that are cancelling at a higher rate. You could then target these groups with special offers or loyalty programs.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
#
# 1. **Marketing and Pricing Strategies:**
# * **No Deposit:** Since this category is popular but has a noticeable cancellation rate, strategies could focus on offering incentives for keeping bookings or implementing flexible cancellation policies to reduce cancellations.
# * **Non Refund:** Given the high cancellation rate, reviewing the non-refundable policy or offering additional benefits for committing to non-refundable bookings might help in reducing cancellations.
# * **Refundable:** This category might need better promotion or adjustment in pricing to make it more attractive to customers.
#
# 2. **Customer Behavior:**
# * The high cancellation rate in Non Refund might indicate that customers book this option as a backup or change their plans more frequently when there's a non-refundable deposit.
# * Strategies could be devised to manage the high cancellation rates in both No Deposit and Non Refund categories to minimize revenue losses and improve booking stability.
# * Identify which countries have the most cancellations:
#  By focusing your marketing efforts on countries with fewer cancellations, you might be able to improve your overall cancellation rate.
# * Investigate reasons for cancellations from specific countries:
# There could be specific reasons why people from certain countries are cancelling reservations more frequently. By researching these reasons, you might be able to take steps to address them and reduce cancellations.
# *Re-evaluate pricing or offerings for specific countries: If you see a correlation between cancellations from a particular country and the price of your hotel stays or the packages you offer, you might want to consider adjusting your pricing or offerings for that country.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# * **Booking and Cancellation Trends:** Understanding the lead time and cancellation rates can help in forecasting future bookings and managing cancellations.
#
# * **Guest Demographics:** Analyzing the number of adults, children, and babies can help tailor services and amenities to different guest types.
#
# * **Stay Patterns:** Observing patterns in weekend and weeknight stays can assist in pricing and promotional strategies.
#
# * **Special Requests:** Tracking special requests can improve guest satisfaction by ensuring common requests are met efficiently.
#
# * **Revenue Management:** The Average Daily Rate (ADR) and booking changes can be monitored to optimize pricing strategies.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
